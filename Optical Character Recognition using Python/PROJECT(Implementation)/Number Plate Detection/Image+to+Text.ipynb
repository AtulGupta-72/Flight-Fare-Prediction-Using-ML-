# %%
import pytesseract
from PIL import Image

# %%
img = Image.open("test.png")

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=500x517 at 0x20F58F787C0>

# %%
pytesseract.image_to_string()
