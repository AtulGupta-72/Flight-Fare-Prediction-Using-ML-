# %%
from PIL import Image
from PIL import ImageDraw

# %%
img = Image.open("testimage.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=812x457 at 0x260E7A7A9A0>

# %%
draw = ImageDraw.Draw(img)

# %%
draw.text((50,90),"Sample Text 123",(255,255,255))

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=812x457 at 0x260E7A7A9A0>
