# %%
from PIL import Image,ImageFilter

# %%
im = Image.open("testimage.jpg")

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=812x457 at 0x2AD80A02BE0>

# %%
im1 = im.filter(ImageFilter.BoxBlur(10))

# %%
im1
# Out:
# <PIL.Image.Image image mode=RGB size=812x457 at 0x2AD80866820>

# %%
im2 = im.filter(ImageFilter.GaussianBlur(5))

# %%
im2
# Out:
# <PIL.Image.Image image mode=RGB size=812x457 at 0x2AD80888B50>

# %%
im3 = im.filter(ImageFilter.BLUR)

# %%
im3
# Out:
# <PIL.Image.Image image mode=RGB size=812x457 at 0x2AD80874100>
