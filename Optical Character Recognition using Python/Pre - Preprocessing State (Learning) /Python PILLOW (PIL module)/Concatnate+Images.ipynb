# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
img = Image.open("testimage.jpg")
img1 = Image.open("testimage2.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=812x457 at 0x16D8E51A4C0>

# %%
img1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=550x343 at 0x16D966B4DC0>

# %%
img.size
# Out:
# (812, 457)

# %%
img1.size
# Out:
# (550, 343)

# %%
img_size = img.resize((250,100))
img1_size = img1.resize((250,100))

# %%
img2 = Image.new("RGB",(500,100),"white")

# %%
img2.paste(img_size,(0,0))

# %%
img2.paste(img1_size,(250,0))

# %%
img2
# Out:
# <PIL.Image.Image image mode=RGB size=500x100 at 0x16D966B4E80>

# %%
img_size = img.resize((250,90))
img1_size = img1.resize((250,90))

# %%
img2 = Image.new("RGB",(250,180),"white")

# %%
img2.paste(img_size,(0,0))

# %%
img2.paste(img1_size,(0,90))

# %%
img2
# Out:
# <PIL.Image.Image image mode=RGB size=250x180 at 0x16D966C5370>
