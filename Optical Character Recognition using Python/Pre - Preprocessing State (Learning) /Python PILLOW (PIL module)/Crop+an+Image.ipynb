# %%
from PIL import Image

# %%
im = Image.open("testimage.jpg")

# %%
im.size
# Out:
# (812, 457)

# %%
width, height = im.size

# %%
width
# Out:
# 812

# %%
height
# Out:
# 457

# %%
left = 5
top = height / 4
right = 164
bottom = 3 * height / 4

# %%
cropped_img = im.crop((left,top,right,bottom))

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=812x457 at 0x219CA4A1CD0>

# %%
cropped_img
# Out:
# <PIL.Image.Image image mode=RGB size=159x229 at 0x219CA198790>
