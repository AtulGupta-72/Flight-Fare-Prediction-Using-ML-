# %%
from PIL import Image

# %%
right = 98
left = 105
top = 100
bottom = 100

# %%
width,height=image.size

# %%
width
# Out:
# 812

# %%
height
# Out:
# 457

# %%
new_width = width + right + left

new_height = height + top + bottom

# %%
result = Image.new(image.mode, (new_width,new_height),(0,0,255))

# %%
result.paste(image,(left,top))

# %%
result
# Out:
# <PIL.Image.Image image mode=RGB size=1015x657 at 0x2374BC35A30>

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=812x457 at 0x2374BC78C70>
