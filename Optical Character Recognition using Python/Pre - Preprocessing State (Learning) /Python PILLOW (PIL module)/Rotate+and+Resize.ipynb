# %%
from PIL import Image

# %%
img = Image.open("testimage.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=812x457 at 0x16960637A00>

# %%
r1_image = img.rotate(90)

# %%
r1_image
# Out:
# <PIL.Image.Image image mode=RGB size=812x457 at 0x169607BEAC0>

# %%
r2_image = img.rotate(180)

# %%
r2_image
# Out:
# <PIL.Image.Image image mode=RGB size=812x457 at 0x169606E3610>

# %%
img.size
# Out:
# (812, 457)

# %%
size = (400,250)

resized_image = img.resize(size)

# %%
resized_image
# Out:
# <PIL.Image.Image image mode=RGB size=400x250 at 0x16960687E50>

# %%
new_size = (200,200)

new_sized_image_1 = img.resize(new_size)

# %%
new_sized_image_1
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x169606310A0>
